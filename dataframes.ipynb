# %%
from pydataset import data

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# 1. A. Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df["passing_english"] = (df.english >= 70)
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# B. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df = df.sort_values(by = "passing_english", ascending = False)
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# ## NB: Always set "df = " after making a change, to apply the change

# %% [markdown]
# C. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df = df.sort_values(by = ["passing_english", "name"], ascending = True)
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 11     Alan    92       62       72            False      75.333333
# 8    Albert    92       62       87            False      80.333333
# 7     Marie    93       63       90            False      82.000000
# 6    Thomas    82       64       81            False      75.666667
# 4       Ada    77       92       98             True      89.000000
# 3     Billy    98       96       88             True      94.000000
# 10    Isaac    92       99       93             True      94.666667
# 1      Jane    88       79       67             True      78.000000
# 5      John    79       76       93             True      82.666667
# 9   Richard    69       80       94             True      81.000000
# 0     Sally    62       85       80             True      75.666667
# 2     Suzie    94       74       95             True      87.666667

# %% [markdown]
# D. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by = ["passing_english", "english"], ascending = True)
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# E. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df["overall_grade"] = round((df.english + df.math + df.reading) /3,0)
df.sort_values(by = 'overall_grade', ascending = False)

#df["overall"] = df[["math", "english", "reading"]].mean(axis=1) >> 
# this gives the row value
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 10    Isaac    92       99       93             True           95.0
# 3     Billy    98       96       88             True           94.0
# 4       Ada    77       92       98             True           89.0
# 2     Suzie    94       74       95             True           88.0
# 5      John    79       76       93             True           83.0
# 7     Marie    93       63       90            False           82.0
# 9   Richard    69       80       94             True           81.0
# 8    Albert    92       62       87            False           80.0
# 1      Jane    88       79       67             True           78.0
# 6    Thomas    82       64       81            False           76.0
# 0     Sally    62       85       80             True           76.0
# 11     Alan    92       62       72            False           75.0

# %%
df.passing_english.sum()
# Out:
# 8

# %%
df.passing_english.mean()
# Out:
# 0.6666666666666666

# %% [markdown]
# ## We can run .sum(), .mean() and other fucntions on the boolean outputs of our tables

# %% [markdown]
# 2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.
# ---------------------------------------------------------------------------
# ...

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg = data('mpg')

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe().round(1)
# Out:
#        displ    year    cyl    cty    hwy
# count  234.0   234.0  234.0  234.0  234.0
# mean     3.5  2003.5    5.9   16.9   23.4
# std      1.3     4.5    1.6    4.3    6.0
# min      1.6  1999.0    4.0    9.0   12.0
# 25%      2.4  1999.0    4.0   14.0   18.0
# 50%      3.3  2003.5    6.0   17.0   24.0
# 75%      4.6  2008.0    8.0   19.0   27.0
# max      7.0  2008.0    8.0   35.0   44.0

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# A. How many rows and columns are there?

# %%
mpg.info() ## 234 rows, 11 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# B. What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# C. Summarize the dataframe with .info and .describe

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe().round(1)
# Out:
#        displ    year    cyl    cty    hwy
# count  234.0   234.0  234.0  234.0  234.0
# mean     3.5  2003.5    5.9   16.9   23.4
# std      1.3     4.5    1.6    4.3    6.0
# min      1.6  1999.0    4.0    9.0   12.0
# 25%      2.4  1999.0    4.0   14.0   18.0
# 50%      3.3  2003.5    6.0   17.0   24.0
# 75%      4.6  2008.0    8.0   19.0   27.0
# max      7.0  2008.0    8.0   35.0   44.0

# %% [markdown]
# D. Rename the cty column to city.
# E. Rename the hwy column to highway.

# %%
mpg = mpg.rename(columns={'cty' : 'city'})
mpg = mpg.rename(columns={'hwy' : 'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# F. Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.city > mpg.highway] #None
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %% [markdown]
# G. Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg["mileage_difference"] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# H. Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by = 'mileage_difference', ascending = False).head(5)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
# 1           audi          a4    1.8  1999    4  auto(l5)   f    18       29
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f    18       29
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f    18       29
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12
# 1    p     compact                  11
# 229  p     midsize                  11
# 36   r     midsize                  11

# %% [markdown]
# I. Which compact class car has the lowest highway mileage? The best?

# %%
mpg[mpg['class'] == "compact"].sort_values(by = 'highway', ascending = False).head(1) ##best

mpg[mpg['class'] == "compact"].sort_values(by = 'highway', ascending = True).head(1) ##worst
#mpg[mpg['class'] == "compact"].sort_values(by = 'highway', ascending = True).head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %% [markdown]
# J.Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg["average_mileage"] = (mpg.highway + mpg.city )/ 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Which dodge car has the best average mileage?
# - caravan
#
# The worst?
# - ram 1500

# %%
mpg[mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage', ascending = True).head(3) #worst

mpg[mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage', ascending = False).head(3) #best
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
#
#    fl    class  mileage_difference  average_mileage
# 38  r  minivan                   6             21.0
# 42  r  minivan                   7             20.5
# 43  r  minivan                   7             20.5

# %% [markdown]
# 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
Mammals = data('Mammals')

# %%
data('Mammals', show_doc = True)
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
Mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
Mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
Mammals.describe().round(4)
# Out:
#           weight     speed
# count   107.0000  107.0000
# mean    278.6882   46.2084
# std     839.6083   26.7168
# min       0.0160    1.6000
# 25%       1.7000   22.5000
# 50%      34.0000   48.0000
# 75%     142.5000   65.0000
# max    6000.0000  110.0000

# %% [markdown]
# A. How many rows and columns are there?

# %%
Mammals.info() #4 columns, 107 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %% [markdown]
# B. What are the data types?

# %%
Mammals.dtypes #float, bool, obj
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# C. Summarize the dataframe with .info and .describe

# %% [markdown]
# D. What is the the weight of the fastest animal?

# %%
Mammals.sort_values(by = ["speed", "weight"], ascending = False).head(1) # also use .min(), .max() 
#functions on columns
#(Mammals.speed == Mammals.speed.max()).head(1)
# Out:
#     weight  speed  hoppers  specials  median_speed  faster_than_mdn
# 53    55.0  110.0    False     False          48.0             True

# %% [markdown]
# E. What is the overal percentage of specials?

# %%
len(Mammals[Mammals["specials"]])/len(Mammals) * 100
## Mammals.specials.mean()
# Out:
# 9.345794392523365

# %% [markdown]
# E. How many animals are hoppers that are above the median speed? What percentage is this?

# %% [markdown]
# ## On the assessment

# %%
Mammals['median_speed'] = Mammals.speed.median()
Mammals
#fast_hoppers = Mammals[(Mammals.hoppers == True) & (Mammals.speed > Mammals.speed.median())]
#len(fast_hoppers)/len(Mammals) * 100
# Out:
#        weight  speed  hoppers  specials  median_speed
# 1    6000.000   35.0    False     False          48.0
# 2    4000.000   26.0    False     False          48.0
# 3    3000.000   25.0    False     False          48.0
# 4    1400.000   45.0    False     False          48.0
# 5     400.000   70.0    False     False          48.0
# 6     350.000   70.0    False     False          48.0
# 7     300.000   64.0    False     False          48.0
# 8     260.000   70.0    False     False          48.0
# 9     250.000   40.0    False     False          48.0
# 10   3800.000   25.0    False      True          48.0
# 11   1000.000   60.0    False     False          48.0
# 12    900.000   70.0    False     False          48.0
# 13    900.000   56.0    False     False          48.0
# 14    800.000   29.0    False     False          48.0
# 15    750.000   57.0    False     False          48.0
# 16    500.000   32.0    False     False          48.0
# ...

# %%
Mammals['faster_than_mdn'] = Mammals.speed > Mammals.median_speed
Mammals
# Out:
#        weight  speed  hoppers  specials  median_speed  faster_than_mdn
# 1    6000.000   35.0    False     False          48.0            False
# 2    4000.000   26.0    False     False          48.0            False
# 3    3000.000   25.0    False     False          48.0            False
# 4    1400.000   45.0    False     False          48.0            False
# 5     400.000   70.0    False     False          48.0             True
# 6     350.000   70.0    False     False          48.0             True
# 7     300.000   64.0    False     False          48.0             True
# 8     260.000   70.0    False     False          48.0             True
# 9     250.000   40.0    False     False          48.0            False
# 10   3800.000   25.0    False      True          48.0            False
# 11   1000.000   60.0    False     False          48.0             True
# 12    900.000   70.0    False     False          48.0             True
# ...

# %%
Mammals.sort_values(by = ["faster_than_mdn" , "hoppers"], ascending = False)
# Out:
#        weight  speed  hoppers  specials  median_speed  faster_than_mdn
# 96      4.600   64.0     True     False          48.0             True
# 97      4.400   72.0     True     False          48.0             True
# 98      4.000   72.0     True     False          48.0             True
# 99      3.500   56.0     True     False          48.0             True
# 100     2.000   64.0     True     False          48.0             True
# 101     1.900   56.0     True     False          48.0             True
# 102     1.500   50.0     True     False          48.0             True
# 5     400.000   70.0    False     False          48.0             True
# 6     350.000   70.0    False     False          48.0             True
# 7     300.000   64.0    False     False          48.0             True
# 8     260.000   70.0    False     False          48.0             True
# 11   1000.000   60.0    False     False          48.0             True
# ...

# %%
len(Mammals[(Mammals["faster_than_mdn"]) & (Mammals["hoppers"]) == True])/len(Mammals) * 100 #calling table ""
#len(Mammals[Mammals["specials"]])/len(Mammals) * 100
# Out:
# 6.5420560747663545

# %% [markdown]
# #calling df "Mammals", then calling columns from Mammals table takes a specific syntax
# len(Mammals[
#     >> then: (Mammals["faster_than_median"]) &

# %%
len(Mammals[Mammals.hoppers & Mammals.faster_than_mdn])/len(Mammals) * 100
# Out:
# 6.5420560747663545

# %% [markdown]
# ^^ This method is simpler, and refers to columns by the "dot" method
